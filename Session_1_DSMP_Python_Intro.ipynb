# %% [markdown]
# <a href="https://colab.research.google.com/github/SanyamSharma26/DSMP-2.0/blob/main/Session_1_DSMP_Python_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1) Python Output

# %%
#Python is a case sensitive language
print('Hello World')
# Out:
# Hello World

# %%
print("SK")
# Out:
# SK

# %%
print(7)
# Out:
# 7

# %%
print(True)
# Out:
# True

# %%
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %%
print('hello')
print('World')
# Out:
# hello
# World

# %%
print('hello',end='-')
print('World')
# Out:
# hello-World

# %% [markdown]
# #2) Data Types

# %%
# Integers
print(8)
print(1e308)
# Out:
# 8
# 1e+308

# %%
#Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
print('Hello World')
# Out:
# Hello World

# %%
#List -> C -> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuples
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#Sets
print({1,2,3,4,5,6})
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# Dictionary
print({'name':'Sanyam','gender':'Male','weight':70})
# Out:
# {'name': 'Sanyam', 'gender': 'Male', 'weight': 70}

# %%
#type function
print(type(3))
print(type([1,2,4]))
# Out:
# <class 'int'>
# <class 'list'>

# %% [markdown]
# #3) Variables

# %%
#Static vs Dynamic Typing
#Static vs Dynamic Binding
#Stylish decleration techniques

# %%
# C/C++
# int name='Sanyam' ----> Not allowed in Python
name='Sanyam'
print(name)

a=5
b=6
print(a+b)
# Out:
# Sanyam
# 11

# %%
#Dynamic Typing
a =5
print(type(a))
# Static Typing
# int a = 5
# Out:
# <class 'int'>

# %%
#Dynamic Binding
a=5
print(a)
a='Sanyam'
print(a)

#Static Binding
# int  a = 5 (like we do in C++)
# Out:
# 5
# Sanyam

# %%
# Some styles to give values to variables
# a,b,c=1,2,3
# print(a,b,c)

a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# #Comments

# %%
# This is a comment
a=4
b=5
# Second Comment
print(a+b)
# Out:
# 9

# %% [markdown]
# #Keywords and Identifiers

# %%
# Keywords

# %%
# Identifiers
# You can't start with a digit

# 1name='Sanyam'
# print(1name)

#But you can end with a digit
name1='Sanyam'
print(name1)

# You can use special chars -> _
# _='Sanyam'
# print(_)

# Identifiers can't be a keyword
# Out:
# Sanyam
# Sanyam

# %% [markdown]
# #5) User Input

# %%
#Static vs Dynamic
input('Enter Email')
# Out:
# Enter Emailssharma3_be22@thapar.edu
# 'ssharma3_be22@thapar.edu'

# %% [markdown]
# #6) Type Conversion

# %%
# Implicit vs Explicit

#Implicit
print(5+5.6)
print(type(5),type(5.6))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
# Take input from user and store them in the variable
fnum = input('Enter first no ')
snum = input('Enter second no ')
print(type(fnum))
print(type(snum))
result = int(fnum)+int(snum)
#print the result
print(result)
# Out:
# Enter first no 12
# Enter second no 21
# <class 'str'>
# <class 'str'>
# 33

# %% [markdown]
# #7) Literals

# %%
a = 0b1010 #Binary Literals
b = 100 # Decimal Lierals
c = 0o310 # Octal Literal
d = 0x12c # Hexadecimal Literal
# Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3

# Complex Literal
x = 3.14j

print(a,b,c,d)
print(float_1,float_2,float_3)
print(x,x.imag,x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
string='This is Python'
strings="This is Python"
char="C"
multiline_str="""This is multiline string with more than one line code"""
unicode=u"\u00dcnic\u00f6de"
raw_str=r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is multiline string with more than one line code
# Ünicöde
# raw \n string

# %%
a=True+4
b=False+10
print("a",a)
print("b",b)
# Out:
# a 5
# b 10

# %%
a=None
print(a)
# Out:
# None

# %%
k=None
a=5
b=6
print('Program exe')
# Out:
# Program exe

# %% [markdown]
# #8) Operators
